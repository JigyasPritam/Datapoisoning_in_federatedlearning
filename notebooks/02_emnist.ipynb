# %%
import torchvision
import torchvision.transforms as transforms

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])

train_data = torchvision.datasets.EMNIST(
    root='../data', split='byclass', train=True, download=True, transform=transform
)
test_data = torchvision.datasets.EMNIST(
    root='../data', split='byclass', train=False, download=True, transform=transform
)

print(f"Train samples: {len(train_data)}")
print(f"Test samples: {len(test_data)}")
print(f"Number of classes: {len(train_data.classes)}")
# Out:
# 100%|██████████| 562M/562M [04:11<00:00, 2.23MB/s]
# Train samples: 697932
# Test samples: 116323
# Number of classes: 62

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 5, figsize=(10, 4))
for i, ax in enumerate(axes.flatten()):
    img, label = train_data[i]
    ax.imshow(img.squeeze(), cmap='gray')
    ax.set_title(f'Label: {train_data.classes[label]}')
    ax.axis('off')
plt.suptitle('EMNIST Sample Images')
plt.tight_layout()
plt.show()

# %%
img, label = train_data[0]

print(f"Image shape: {img.shape}")
print(f"Min value: {img.min():.4f}")
print(f"Max value: {img.max():.4f}")
print(f"Total train samples: {len(train_data)}")
print(f"Total test samples: {len(test_data)}")
print(f"Number of classes: {len(train_data.classes)}")
# Out:
# Image shape: torch.Size([1, 28, 28])
# Min value: -0.4242
# Max value: 2.8215
# Total train samples: 697932
# Total test samples: 116323
# Number of classes: 62
